# %% [markdown]
# # Funciones de distribución de probabilidades
# ## Distribución Uniforme

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = 1
b = 100
n = 200
data = np.random.uniform(a, b, n)

# %%
# %matplotlib inline
plt.hist(data)
# Out:
# (array([12., 19., 15., 17., 24., 15., 31., 19., 32., 16.]),
#  array([ 1.06407351, 10.84040045, 20.61672739, 30.39305433, 40.16938126,
#         49.9457082 , 59.72203514, 69.49836208, 79.27468901, 89.05101595,
#         98.82734289]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Distribución Normal

# %%
a = 10000
data = np.random.randn(a) #genera una distribución normal std con media 0

# %%
x = range(0,a)
plt.plot(x, data)

# %%
plt.hist(data)
# Out:
# (array([7.000e+00, 7.900e+01, 5.100e+02, 1.794e+03, 3.094e+03, 2.719e+03,
#         1.430e+03, 3.270e+02, 3.700e+01, 3.000e+00]),
#  array([-4.0159797 , -3.19037403, -2.36476836, -1.5391627 , -0.71355703,
#          0.11204864,  0.93765431,  1.76325997,  2.58886564,  3.41447131,
#          4.24007698]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(x, sorted(data))

# %%
mu = 5.5
sd = 2.5
data = mu + sd*np.random.randn(a) # Z = (X-mu)/sd-->N(0,1)
plt.hist(data)
# Out:
# (array([  28.,  158.,  678., 1666., 2646., 2610., 1490.,  603.,  105.,
#           16.]),
#  array([-3.2275363 , -1.45571178,  0.31611273,  2.08793725,  3.85976177,
#          5.63158629,  7.4034108 ,  9.17523532, 10.94705984, 12.71888436,
#         14.49070887]),
#  <a list of 10 Patch objects>)

# %%
data = np.random.randn(2,4) # son dos colecciones de 4 elementos cada uno. Cada array es una dist. normal
data
# Out:
# array([[-1.44979023,  1.54433866, -0.60854772,  0.15343954],
#        [-0.0264791 ,  0.83318396, -2.01949565,  1.12760019]])

# %% [markdown]
# ## Simulación de Monte Carlo

# %% [markdown]
# * Generar dos número aleatorios entre 0 y 1
# * Calcular x2 + y2
#     * si es mayor que 1 estamos fuera del círculo
#     * si es menor que 1 estamos dentro del círculo
# * Calculamos el número total de veces que están dentro del círculo y lo dividimos por el número de intentos para obtener una aproximación de la probabilidad de caer dentro del círculo.
# * Dicha probabilidad la utilizamos para aproximar el valor de pi. (la probabilidad teórica es pi/4
# * Repetimos el experimento un número suficiente de veces, para obtener diferentes aproximaciones de pi.
# * Luego calculamos el promedio del mil experimentos para obtener un valor final.

# %%
n = 100
exp = 50
pi_sum = 0
pi_value_list = []
for i in range(exp):
    value = 0
    x = np.random.uniform(0,1,n).tolist()
    y = np.random.uniform(0,1,n).tolist()
    for j in range(n):
        z = np.sqrt(x[j]*x[j]+y[j]*y[j])
        if z <=1:
            value+=1
    float_value = float(value)
    pi_value = float_value*4 / n
    pi_value_list.append(pi_value)
    pi_sum += pi_value

pi = pi_sum/exp

print(pi)
plt.plot(pi_value_list)
# Out:
# 3.1472
