# %% [markdown]
# # Dimensiones y estructuras

# %%
# %config IPCompleter.greedy=True

# %%
import pandas as pd
import os

# %%
mainpath = "C:/Users/Agustin Ianchina/OneDrive/Documents/GitHub/python-ml-course/datasets"
titanic3_csv = "titanic/titanic3.csv"
customer_churn_model_txt = "customer-churn-model\Customer Churn Model.txt"
fullpathtitanic3csv = os.path.join(mainpath, titanic3_csv)
fullpathcustomer_churn_model_txt = os.path.join(mainpath, customer_churn_model_txt)
titanic3_csv = 'C:/Users/Agustin Ianchina/OneDrive/Documents/GitHub/python-ml-course/datasets/titanic/titanic3.csv'
df_titanic3_csv = pd.read_csv(fullpathtitanic3csv)
df_titanic3_csv.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
df_titanic3_csv.shape
# Out:
# (1309, 14)

# %%
df_titanic3_csv.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
df_titanic3_csv.columns.values
# Out:
# array(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype=object)

# %%
df_titanic3_csv.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df_titanic3_csv.describe(include="all")
# Out:
#              pclass     survived                  name   sex          age  \
# count   1309.000000  1309.000000                  1309  1309  1046.000000
# unique          NaN          NaN                  1307     2          NaN
# top             NaN          NaN  Connolly, Miss. Kate  male          NaN
# freq            NaN          NaN                     2   843          NaN
# mean       2.294882     0.381971                   NaN   NaN    29.881135
# std        0.837836     0.486055                   NaN   NaN    14.413500
# min        1.000000     0.000000                   NaN   NaN     0.166700
# 25%        2.000000     0.000000                   NaN   NaN    21.000000
# 50%        3.000000     0.000000                   NaN   NaN    28.000000
# 75%        3.000000     1.000000                   NaN   NaN    39.000000
# max        3.000000     1.000000                   NaN   NaN    80.000000
#
#               sibsp        parch    ticket         fare        cabin embarked  \
# ...

# %%
df_titanic3_csv.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
df_titanic3_csv.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %% [markdown]
# # Missing Values

# %%
pd.isnull(df_titanic3_csv["body"])
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 1304    False
# 1305     True
# 1306    False
# 1307     True
# 1308     True
# Name: body, Length: 1309, dtype: bool

# %%
pd.notnull(df_titanic3_csv["body"])
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1304     True
# 1305    False
# 1306     True
# 1307    False
# 1308    False
# Name: body, Length: 1309, dtype: bool

# %%
pd.isnull(df_titanic3_csv["body"]).values.ravel().sum()
# Out:
# 1188

# %%
pd.notnull(df_titanic3_csv["body"]).values.ravel().sum()
# Out:
# 121

# %% [markdown]
# Los valores de un dataset pueden faltar por lo siguiente:
# * extracción de los datos.(por ej del csv al fichero)
# * recolección de los datos. (por ej de marcaciones a la base de datos)

# %% [markdown]
# ### Borrado de valores que falten

# %%
df_titanic3_csv.dropna(axis=0, how="all")
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
data2 = df_titanic3_csv

# %%
data2.dropna(axis=0, how="any")
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %% [markdown]
# ### Cómputo de valores que faltan

# %%
data3=df_titanic3_csv

# %%
data3.fillna(0)
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
data4 = df_titanic3_csv

# %%
data4.fillna("Desconocido")
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex          age  sibsp  parch  ticket     fare        cabin  \
# ...

# %%
data5=df_titanic3_csv

# %%
data5["body"].fillna(0)
data5["home.dest"].fillna("Desconocido")
data5
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
pd.isnull(data5["age"]).values.ravel().sum()
# Out:
# 263

# %%
print(df_titanic3_csv["age"].mean())
data5["age"].fillna(df_titanic3_csv["age"].mean())
# Out:
# 29.8811345124283
# 0       29.000000
# 1        0.916700
# 2        2.000000
# 3       30.000000
# 4       25.000000
#           ...
# 1304    14.500000
# 1305    29.881135
# 1306    26.500000
# 1307    27.000000
# 1308    29.000000
# Name: age, Length: 1309, dtype: float64

# %%
data5["age"][1291]
# Out:
# nan

# %%
data5["age"].fillna(method="ffill")
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305    14.5000
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
data5["age"].fillna(method="bfill")
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305    26.5000
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %% [markdown]
# # Variables Dummy

# %%
df=df_titanic3_csv

# %%
df["sex"]
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
#          ...
# 1304    female
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: sex, Length: 1309, dtype: object

# %%
dummy_sex = pd.get_dummies(df["sex"],prefix = "sex")
dummy_sex.head()
# Out:
#    sex_female  sex_male
# 0           1         0
# 1           0         1
# 2           1         0
# 3           0         1
# 4           1         0

# %%
df = df.drop(columns="sex", axis = 1)

# %%
df.head(1)
# Out:
#    pclass  survived                           name   age  sibsp  parch ticket  \
# 0       1         1  Allen, Miss. Elisabeth Walton  29.0      0      0  24160
#
#        fare cabin embarked boat  body     home.dest
# 0  211.3375    B5        S    2   NaN  St Louis, MO

# %%
pd.concat([df,dummy_sex], axis=1)
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#           age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# ...

# %%
data5.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
pd.get_dummies(data5, columns=["sex"], prefix="sex", drop_first=True)
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#           age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# ...

# %%
pd.get_dummies(data4, columns=["sex"], prefix = "sex")
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#           age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# ...
